# %%
import matplotlib.pyplot as plt

# %%
z_list = [2, 4, 8, 12, 16, 24, 32, 48, 64]
rep_dims = []
rep_dims.append([2, 4, 8, 11, 15, 23, 30, 38, 45])
rep_dims.append([0, 0, 0, 1, 1, 1, 2, 10, 19])

# %%
### stacked bar plot
colors = ['blue', 'orange', 'green']
plt.bar(z_list, rep_dims[0], 2, color='lightsalmon', label='Z1')
plt.bar(z_list, rep_dims[1], 2, color='grey', label='Z2 ', bottom=rep_dims[0])
plt.ylabel("Latenet dimension")
plt.xlabel("Latent Dimension")
plt.legend(loc="upper left")
# plt.title('Importance of representations (fully recon)')
plt.savefig('./z_importance.png', bbox_inches='tight', dpi=300)
plt.show()
